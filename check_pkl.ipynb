# %%
import pickle

with open("/share/nas169/jethrowang/DB/pkl/train_both.pkl", "rb") as f:
    data = pickle.load(f)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#         wav_label                                                wav  \
# 0  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 1  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 2  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 3  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 4  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
#
#              text  duration label             type  \
# 0  that is to say      0.71     1  diffspk_easyneg
# 1  that is to say      0.76     1  diffspk_easyneg
# 2  that is to say      0.76     1  diffspk_easyneg
# 3  that is to say      0.82     1  diffspk_easyneg
# 4  that is to say      0.82     1  diffspk_easyneg
#
#                                          phoneme  \
# 0  [TH, AE1, T,  , IH1, Z,  , T, OW1,  , S, EY1]
# 1  [TH, AE1, T,  , IH1, Z,  , T, OW1,  , S, EY1]
# 2  [TH, AE1, T,  , IH1, Z,  , T, OW1,  , S, EY1]
# ...

# %%
data.columns
# Out:
# Index(['wav_label', 'wav', 'text', 'duration', 'label', 'type', 'phoneme',
#        'wav_phoneme', 'pIndex', 'wav_pIndex', 'g2p_embed', 'dist'],
#       dtype='object')

# %%
data.dtypes
# Out:
# wav_label       object
# wav             object
# text            object
# duration       float64
# label           object
# type            object
# phoneme         object
# wav_phoneme     object
# pIndex          object
# wav_pIndex      object
# g2p_embed       object
# dist           float64
# dtype: object

# %%
data.describe()
# Out:
#             duration           dist
# count  730296.000000  730296.000000
# mean        0.648327       0.833826
# std         0.137867       0.277905
# min         0.500000       0.000000
# 25%         0.550000       0.750000
# 50%         0.610000       1.000000
# 75%         0.710000       1.000000
# max         1.990000       1.000000

# %%
data.shape
# Out:
# (730296, 12)

# %%
data.head(100)
# Out:
#          wav_label                                                wav  \
# 0   that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 1   that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 2   that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 3   that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 4   that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# ..             ...                                                ...
# 95  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 96  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 97  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 98  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
# 99  that is to say  /share/nas169/albertali/Libriphrase/LibriPhras...
#
#                 text  duration label              type  \
# 0     that is to say      0.71     1   diffspk_easyneg
# ...

# %%
data.to_csv('/share/nas169/jethrowang/DB/csv/train_both.csv', index=False)

# %%
data.iloc[80:90]
# Out:
#                                                   wav            text  \
# 80  /share/nas169/albertali/Zero-shot-phonmatchnet...     hey android
# 81  /share/nas169/albertali/Zero-shot-phonmatchnet...  hey snapdragon
# 82  /share/nas169/albertali/Zero-shot-phonmatchnet...       hi galaxy
# 83  /share/nas169/albertali/Zero-shot-phonmatchnet...       hi lumina
# 84  /share/nas169/albertali/Zero-shot-phonmatchnet...     hey android
# 85  /share/nas169/albertali/Zero-shot-phonmatchnet...  hey snapdragon
# 86  /share/nas169/albertali/Zero-shot-phonmatchnet...       hi galaxy
# 87  /share/nas169/albertali/Zero-shot-phonmatchnet...       hi lumina
# 88  /share/nas169/albertali/Zero-shot-phonmatchnet...     hey android
# 89  /share/nas169/albertali/Zero-shot-phonmatchnet...  hey snapdragon
#
#     duration label                                           phoneme  \
# 80  0.925125     1                [HH, EY1,  , AE1, N, D, R, OY2, D]
# ...
